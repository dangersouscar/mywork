# %%
import tushare as ts
import pandas as pd
import numpy as np
import sqlite3
import time
import datetime
con=sqlite3.connect("db")
cur = con.cursor()
print(con)
ts.set_token("030340d5dee462cf170d55e914589d0f530f8bac1f067bd94c87b2a4")
pro = ts.pro_api()
##############################################################################

def stockholder ():
    data = ts.fund_holdings(2019, 4)
    print(data)
    data.to_sql('stockholder', con=con, if_exists='append', index=None)




##############################################################################
def upinformation (ts_code):
    ts_code=ts_code
    end_date = time.strftime("%Y%m%d",time.localtime(time.time()))
    def get_date(days):
        start_date=datetime.datetime.now() - datetime.timedelta(days = days)
        return str(start_date)[0:10].replace("-", "" )
    print(str(ts_code))
    start_date1=get_date(5000)
    start_date2=get_date(10000)
    start_date3=get_date(15000)
    df1 = pro.daily(ts_code=ts_code, start_date=start_date1, end_date=end_date)
    df2 = pro.daily(ts_code=ts_code, start_date=start_date2, end_date=start_date1)
    df3 = pro.daily(ts_code=ts_code, start_date=start_date3, end_date=start_date2)

    dataset1=pd.DataFrame(df1)
    dataset2=pd.DataFrame(df2)
    dataset3=pd.DataFrame(df3)
    dataset1.to_sql(name=str(ts_code), con=con, if_exists='replace', index=None)
    dataset2.to_sql(name=str(ts_code), con=con, if_exists='append', index=None)
    dataset3.to_sql(name=str(ts_code), con=con, if_exists='append', index=None)
    
##############################################################################
def stockname ():
    data = pro.query('stock_basic', exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')
    print(data)
    data.to_sql('stock_basic', con=con, if_exists='append', index=None)
##############################################################################
def allstock():
    cur.execute("select ts_code from  stock_basic")
    rows = cur.fetchall()
    rows = np.array(rows)  
    for i in range(len(rows)):
        time.sleep(0.5)
        try:
            upinformation (str(rows[i][0]))
        except OSError:
            pass
        continue
##############################################################################
def get_h_data ():
    data = ('002352.SZ') #前复权
    data.to_sql('深圳', con=con, if_exists='append', index=None)
##############################################################################
def fund_basic ():
    data = pro.fund_basic(market='E')
    data.to_sql('fund_basic', con=con, if_exists='append', index=None)
##############################################################################
def fund_basic ():
    data = pro.fund_basic(market='E')
    data.to_sql('get_report_data', con=con, if_exists='append', index=None)
##############################################################################
def fina_indicator ():
    data =  pro.fina_indicator(ts_code='600000.SH')
    print(data)
    data.to_sql('get_report_data', con=con, if_exists='append', index=None)
##stockname()
##allstock()
##stockholder()
fund_basic ()
##ts_code="600690.SH"
#fina_indicator()

# %%
#爬取当前股票历史交易数据
import tushare as ts
import pandas as pd
import numpy as np
import sqlite3
import time
import datetime
con=sqlite3.connect("db")
cur = con.cursor()
print(con)
ts.set_token("030340d5dee462cf170d55e914589d0f530f8bac1f067bd94c87b2a4")
pro = ts.pro_api()

def upinformation (ts_code):
    ts_code=ts_code
    end_date = time.strftime("%Y%m%d",time.localtime(time.time()))
    def get_date(days):
        start_date=datetime.datetime.now() - datetime.timedelta(days = days)
        return str(start_date)[0:10].replace("-", "" )
    print(str(ts_code))
    start_date1=get_date(5000)
    start_date2=get_date(10000)
    start_date3=get_date(15000)
    df1 = pro.daily(ts_code=ts_code, start_date=start_date1, end_date=end_date)
    df2 = pro.daily(ts_code=ts_code, start_date=start_date2, end_date=start_date1)
    df3 = pro.daily(ts_code=ts_code, start_date=start_date3, end_date=start_date2)

    dataset1=pd.DataFrame(df1)
    dataset2=pd.DataFrame(df2)
    dataset3=pd.DataFrame(df3)
    df=pd.concat([dataset1,dataset2,dataset3],axis=0)
    df.to_excel('历史交易量.xls')

upinformation("600153.SH")
# Out:
# ...
# 600153.SH

# %%
# coding = utf-8
"""
@author: zhou
@time:2019/9/3 20:11
@File: main.py
"""
#爬取实时股票价格

import requests
from bs4 import BeautifulSoup
import os
import time
import pandas as pd
a=["http://3.push2.eastmoney.com/api/qt/clist/get?cb=jQuery1124006546135398670994_1595003127442&pn=1&pz=5&po=1&np=1&ut=bd1d9ddb04089700cf9c27f6f7426281&fltt=2&invt=2&fid=f3&fs=m:0+t:6,m:0+t:13,m:0+t:80,m:1+t:2,m:1+t:23&fields=f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f22,f11,f62,f128,f136,f115,f152&_=1595003127454"]



def get_data():
    url = "http://3.push2.eastmoney.com/api/qt/clist/get?cb=jQuery1124006546135398670994_1595003127442&pn=1&pz=5000&po=1&np=1&ut=bd1d9ddb04089700cf9c27f6f7426281&fltt=2&invt=2&fid=f3&fs=m:0+t:6,m:0+t:13,m:0+t:80,m:1+t:2,m:1+t:23&fields=f2,f5,f6,f9,f12,f14,f23&_=1595003127454"
    
    for i in range(1, 2):
        try:
            print(i)
            #url=url.replace("&p=1","&p="+str(i)).replace("&rt=5313802","&rt="+str(5313802+i))
            res1=str(requests.get(url).text)
            res1=res1[43:]
            data=res1.replace(");","").replace("null","").replace("true","").replace("false","")
            data=eval(data)
            data=data["data"]["diff"]
            df=pd.DataFrame(data)
            print(df)
            df.columns = ['最新价','成效量手','成交额元','市盈率','代码','名称','市净率']
            df.to_excel('当日行情.xls')
            time.sleep(5)
        except:
            continue       
if __name__ == '__main__':
    get_data()
# Out:
# 1
#           f2       f5           f6      f9     f12   f14    f23
# 0      33.96     1919  6.50206e+06   33.73  003019   N宸展   3.63
# 1       28.2   200084  5.16903e+08  244.69  300549  优德精密   7.37
# 2      41.06   281617  1.05384e+09   90.18  300727  润禾材料   8.88
# 3       3.86  1342799  4.88621e+08   -7.26  300064  ST金刚   3.75
# 4       70.7   156050  9.95343e+08  236.46  688135  利扬芯片   10.1
# ...      ...      ...          ...     ...     ...   ...    ...
# 4221   11.05   174746  1.97528e+08   76.01  002331  皖通科技   2.07
# 4222   19.85   170036   3.4697e+08  528.33  002785   万里石   6.38
# 4223    2.85  2053669  6.10164e+08  -21.45  600321  正源股份   1.69
# 4224   95.93    47233  4.70908e+08   51.29  300724  捷佳伟创  10.43
# 4225  119.65   468365  5.71684e+09   57.93  300122  智飞生物  25.78
#
# [4226 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dbd883db58b7> in <module>
# ----> 1 print(data)
#
# NameError: name 'data' is not defined

# %%
#爬取东方财富网历年财务报表

# coding = utf-8
"""
@author: zhou
@time:2019/9/3 20:11
@File: main.py
"""
name="2020-09-30"
a=["http://datacenter.eastmoney.com/api/data/get?type=RPT_LICO_FN_CPD&sty=ALL&p
http://datacenter.eastmoney.com/api/data/get?type=RPT_LICO_FN_CPD&sty=ALL&p=34&ps=500&st=UPDATE_DATE,SECURITY_CODE&sr=-1,-1&var=rrPjBPhV&filter=(REPORTDATE=%272015-06-30%27)&rt=53140823","http://datacenter.eastmoney.com/api/data/get?type=RPT_LICO_FN_CPD&sty=ALL&p=35&ps=500&st=UPDATE_DATE,SECURITY_CODE&sr=-1,-1&var=PKknSMrU&filter=(REPORTDATE=%272015-06-30%27)&rt=53140824"]
x=len(a)
url=[]
for i in range(0,x):
    url.append(a[i].replace("2015-06-30",name))   
import requests
from bs4 import BeautifulSoup
import os
import time
import json
import pandas as pd
def get_data(i,url):
    url = url[i]
    print(url)
    res = requests.get(url).text
    res1=str(requests.get(url).text)
    res1=res1[13:]
    data=res1.replace(";","").replace("null",str(0)).replace("true",str(0)).replace("false",str(0))
    data=eval(data)
    data=data["result"]["data"]
    save_to_csv(data) 
    time.sleep(5)
def save_to_csv(data):
    if not os.path.exists(name+'.csv'):
        with open(name+'.csv', 'a+', encoding='utf-8') as f:
            f.write('股票代码,股票简称,交易板块,截止日期,每股收益元,营业收入（元）,净利润,净资产收益率%,营业收入同比增长率%,净利润同比增长率%,每股净资产,每股经营现金流量,销售毛利率%,所属行业\n')
            for d in data:
                try:
                    row = '{},{},{},{},{},{},{},{},{},{},{},{},{},{}'.format(d['SECURITY_CODE'],
                                                                                            d['SECURITY_NAME_ABBR'],
                                                                                            d['TRADE_MARKET'],
                                                                                            d['REPORTDATE'],
                                                                                            d['BASIC_EPS'],
                                                                                            d['TOTAL_OPERATE_INCOME'],
                                                                                            d['PARENT_NETPROFIT'],
                                                                                            d['WEIGHTAVG_ROE'],
                                                                                            d['YSTZ'],
                                                                                            d['SJLTZ'],
                                                                                            d['BPS'],
                                                                                            d['MGJYXJJE'],
                                                                                            d['XSMLL'],
                                                                                            d['PUBLISHNAME'])
                    f.write(row)
                    f.write('\n')
                except:
                    continue
    else:
        with open(name+'.csv', 'a+', encoding='utf-8') as f:
            for d in data:
                try:
                    row = '{},{},{},{},{},{},{},{},{},{},{},{},{},{}'.format(d['SECURITY_CODE'],
                                                                                            d['SECURITY_NAME_ABBR'],
                                                                                            d['TRADE_MARKET'],
                                                                                            d['REPORTDATE'],
                                                                                            d['BASIC_EPS'],
                                                                                            d['TOTAL_OPERATE_INCOME'],
                                                                                            d['PARENT_NETPROFIT'],
                                                                                            d['WEIGHTAVG_ROE'],
                                                                                            d['YSTZ'],
                                                                                            d['SJLTZ'],
                                                                                            d['BPS'],
                                                                                            d['MGJYXJJE'],
                                                                                            d['XSMLL'],
                                                                                            d['PUBLISHNAME'])
                    f.write(row)
                    f.write('\n')
                except:
                    continue

      


if __name__ == '__main__':
    list=[]
    for i in range(4,7):
        time.sleep(5)
        try:
            get_data(i,url)
            print(i)
        except:
            print("error")
            list.append(i)
            print(i)
            continue
# Out:
# http://datacenter.eastmoney.com/api/data/get?type=RPT_LICO_FN_CPD&sty=ALL&p=5&ps=500&st=UPDATE_DATE,SECURITY_CODE&sr=-1,-1&var=AYErkFvp&filter=(REPORTDATE=%272020-09-30%27)&rt=53140798
# 4
# http://datacenter.eastmoney.com/api/data/get?type=RPT_LICO_FN_CPD&sty=ALL&p=6&ps=500&st=UPDATE_DATE,SECURITY_CODE&sr=-1,-1&var=cueWIjdS&filter=(REPORTDATE=%272020-09-30%27)&rt=53140798
# 5
# http://datacenter.eastmoney.com/api/data/get?type=RPT_LICO_FN_CPD&sty=ALL&p=7&ps=500&st=UPDATE_DATE,SECURITY_CODE&sr=-1,-1&var
5HR4nHDL%26ck%3D6556.1.87.368.178.447.166.465%26dt%3D1594293637%26wd%3D%25E5%2590%258C%25E7%25A8%258B%25E8%2589%25BA%25E9%25BE%2599%26tpl%3Dtpl_11534_22836_18980%26l%3D1518847677%26us%3DlinkName%253D%2525E6%2525A0%252587%2525E5%252587%252586%2525E5%2525A4%2525B4%2525E9%252583%2525A8-%2525E4%2525B8%2525BB%2525E6%2525A0%252587%2525E9%2525A2%252598%2526linkText%253D%2525E5%252590%25258C%2525E7%2525A8%25258B%2525E6%252597%252585%2525E8%2525A1%25258C%2525E5%2525AE%252598%2525E7%2525BD%252591-%2525E5%252585%2525A8%2525E6%252596%2525B0%2525E5%252593%252581%2525E7%252589%25258C%2525E5%25258D%252587%2525E7%2525BA%2525A7%2525EF%2525BC%25258C%2525E5%252586%25258D%2525E5%252587%2525BA%2525E5%25258F%252591%2525EF%2525BC%25258C%2525E5%2525B0%2525B1%2525E5%252590%25258C%2525E7%2525A8%25258B%2525EF%2525BC%252581%2526linkType%253D; qdid=39264|1|6928722|0a6c16; route=aa2f4a4e5099ff74807cc36c6b779467; __tctma=144323752.157598320297235.1575983202876.1593854672058.1594293644198.10; __tctmu=144323752.0.0; __tctmz=144323752.1594293644198.10.1.utmccn=(organic)|utmcmd=organic|utmEsl=gb2312|utmcsr=baidu|utmctr=%e5%90%8c%e7%a8%8b%e8%89%ba%e9%be%99; longKey=157598320297235; __tctrack=0; Hm_lvt_c6a93e2a75a5b1ef9fb5d4553a2226e5=1593854757,1594293665; __tctmc=144323752.198976937; __tctmd=144323752.4851125; __tctmb=144323752.2032923904912516.1594293666021.1594293683924.3; Hm_lpvt_c6a93e2a75a5b1ef9fb5d4553a2226e5=1594293683; _dx_app_bc4b3ca6ae27747981b43e9f4a6aa769=5f06fdb85qQWfVsbgGtlrJI8dMWdCsNJIptMetx1; monitor_count=4',
    'Host':' www.ly.com',
    'Origin':' https://www.ly.com',
    'Referer':' https://www.ly.com/flights/itinerary/oneway/SHA-PEK?date=2020-07-15&from=%E4%B8%8A%E6%B5%B7&to=%E5%8C%97%E4%BA%AC&childticket=0,0',
    'refid':' 4140683',
    'Sec-Fetch-Mode':' cors',
    'Sec-Fetch-Site':' same-origin',
    'tcplat':' 1',
    'tcsectoken':' ',
    'tcsessionid':' undefined-1594293682634',
    'tctracerid':' undefined-1594293682634',
    'tcuserid':' ',
    'tcversion':' 1.1.0',
    'User-Agent':' Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'}
data={
    'Arrival':'PEK',
    'ArrivalFilter':'',
    'ArrivalName':'北京',
    'Departure':'SHA',
    'DepartureDate':'2020-07-18',
    'DepartureFilter':'',
    'DepartureName':'上海',
    'GetType':1,
    'IsBaby':0,
    'QueryType':1,
    'flat':' 1',
    'isFromKylin':1,
    'paging':{'dataflag':'all'},
    'plat':1,
    'refid':4140683}
    
    

import requests
from bs4 import BeautifulSoup
import os
import time
import pandas as pd
import json

def get_data(data,headers):
    url = a
    print(url)
    json.dumps(data)
    data['DepartureDate']="2020-08-23"
    print(data['DepartureDate'])
    json.dumps(headers)
    res1=requests.post(url,data=data)
    res1=res1.text
    data=res1.replace("null","None").replace("true","None").replace("false","None")
    data=eval(data)
    data=data["body"]["FlightInfoSimpleList"]
    result=pd.DataFrame(data)
    #print(result.head(5))
    result=result.loc[:,["flightNo","airCompanyName","cfts","arrivalTime"]]
    #print(result)
    remark=[[],[]]
    for i in result["cfts"]:
        remark[0].append(i[0]["ap"])
        remark[1].append(i[0]["cp"])
    remark=pd.DataFrame(remark).T
    remark.columns = ['first','second']
    df=pd.concat([result,remark],axis=1)
    df= df.drop(['cfts'],axis=1)
    print(df)
    pd.DataFrame(df).to_csv('机票价格.csv')
def save_to_csv(data):
    if not os.path.exists(r'2017-12-31.csv'):
        with open('2017-12-31.csv', 'a+', encoding='utf-8') as f:
            f.write('股票代码,股票简称,交易板块,截止日期,每股收益元,营业收入（元）,净利润,净资产收益率%,营业收入同比增长率%,净利润同比增长率%,每股净资产,每股经营现金流量,销售毛利率%,所属行业\n')
            for d in data:
                try:
                    row = '{},{},{},{},{},{},{},{},{},{},{},{},{},{}'.format(d['SECURITY_CODE'],
                                                                                            d['SECURITY_NAME_ABBR'],
                                                                                            d['TRADE_MARKET'],
                                                                                            d['REPORTDATE'],
                                                                                            d['BASIC_EPS'],
                                                                                            d['TOTAL_OPERATE_INCOME'],
                                                                                            d['PARENT_NETPROFIT'],
                                                                                            d['WEIGHTAVG_ROE'],
                                                                                            d['YSTZ'],
                                                                                            d['SJLTZ'],
                                                                                            d['BPS'],
                                                                                            d['MGJYXJJE'],
                                                                                            d['XSMLL'],
                                                                                            d['PUBLISHNAME'])
                    f.write(row)
                    f.write('\n')
                except:
                    continue
    else:
        with open('2017-12-31.csv', 'a+', encoding='utf-8') as f:
            for d in data:
                try:
                    row = '{},{},{},{},{},{},{},{},{},{},{},{},{},{}'.format(d['SECURITY_CODE'],
                                                                                            d['SECURITY_NAME_ABBR'],
                                                                                            d['TRADE_MARKET'],
                                                                                            d['REPORTDATE'],
                                                                                            d['BASIC_EPS'],
                                                                                            d['TOTAL_OPERATE_INCOME'],
                                                                                            d['PARENT_NETPROFIT'],
                                                                                            d['WEIGHTAVG_ROE'],
                                                                                            d['YSTZ'],
                                                                                            d['SJLTZ'],
                                                                                            d['BPS'],
                                                                                            d['MGJYXJJE'],
                                                                                            d['XSMLL'],
                                                                                            d['PUBLISHNAME'])
                    f.write(row)
                    f.write('\n')
                except:
                    continue

      


if __name__ == '__main__':
    get_data(data,headers)

# %%
#爬取国外机票
a="https://www.ly.com/flights/api/getflightlist"
headers={
    'Accept':' application/json, text/plain, */*',
    'Accept-Encoding':' gzip, deflate, br',
    'Accept-Language':' zh-CN,zh;q=0.9',
    'Connection':' keep-alive',
    'Content-Length':' 273',
    'Content-Type':'application/json;charset=UTF-8',
%2525E6%2525A0%252587%2525E9%2525A2%252598%2526linkText%253D%2525E5%252590%25258C%2525E7%2525A8%25258B%2525E6%252597%252585%2525E8%2525A1%25258C%2525E5%2525AE%252598%2525E7%2525BD%252591-%2525E5%252585%2525A8%2525E6%252596%2525B0%2525E5%252593%252581%2525E7%252589%25258C%2525E5%25258D%252587%2525E7%2525BA%2525A7%2525EF%2525BC%25258C%2525E5%252586%25258D%2525E5%252587%2525BA%2525E5%25258F%252591%2525EF%2525BC%25258C%2525E5%2525B0%2525B1%2525E5%252590%25258C%2525E7%2525A8%25258B%2525EF%2525BC%252581%2526linkType%253D; qdid=39264|1|6928722|0a6c16; route=aa2f4a4e5099ff74807cc36c6b779467; __tctma=144323752.157598320297235.1575983202876.1593854672058.1594293644198.10; __tctmu=144323752.0.0; __tctmz=144323752.1594293644198.10.1.utmccn=(organic)|utmcmd=organic|utmEsl=gb2312|utmcsr=baidu|utmctr=%e5%90%8c%e7%a8%8b%e8%89%ba%e9%be%99; longKey=157598320297235; __tctrack=0; Hm_lvt_c6a93e2a75a5b1ef9fb5d4553a2226e5=1593854757,1594293665; __tctmc=144323752.198976937; __tctmd=144323752.4851125; __tctmb=144323752.2032923904912516.1594293666021.1594293683924.3; Hm_lpvt_c6a93e2a75a5b1ef9fb5d4553a2226e5=1594293683; _dx_app_bc4b3ca6ae27747981b43e9f4a6aa769=5f06fdb85qQWfVsbgGtlrJI8dMWdCsNJIptMetx1; monitor_count=4',
    'Host':' www.ly.com',
    'Origin':' https://www.ly.com',
    'Referer':' https://www.ly.com/flights/itinerary/oneway/SHA-PEK?date=2020-07-15&from=%E4%B8%8A%E6%B5%B7&to=%E5%8C%97%E4%BA%AC&childticket=0,0',
    'refid':' 4140683',
    'Sec-Fetch-Mode':' cors',
    'Sec-Fetch-Site':' same-origin',
    'tcplat':' 1',
    'tcsectoken':' ',
    'tcsessionid':' undefined-1594293682634',
    'tctracerid':' undefined-1594293682634',
    'tcuserid':' ',
    'tcversion':' 1.1.0',
    'User-Agent':' Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'}
data={
    'Arrival':'PEK',
    'ArrivalFilter':'',
    'ArrivalName':'北京',
    'Departure':'SHA',
    'DepartureDate':'2020-07-18',
    'DepartureFilter':'',
    'DepartureName':'上海',
    'GetType':1,
    'IsBaby':0,
    'QueryType':1,
    'flat':' 1',
    'isFromKylin':1,
    'paging':{'dataflag':'all'},
    'plat':1,
    'refid':4140683}
    
    

import requests
from bs4 import BeautifulSoup
import os
import time
import pandas as pd
import json

def get_data(data,headers):
    url = a
    print(url)
    json.dumps(data)
    data['DepartureDate']="2020-08-23"
    print(data['DepartureDate'])
    json.dumps(headers)
    res1=requests.post(url,data=data)
    res1=res1.text
    data=res1.replace("null","None").replace("true","None").replace("false","None")
    data=eval(data)
    data=data["body"]["FlightInfoSimpleList"]
    result=pd.DataFrame(data)
    #print(result.head(5))
    result=result.loc[:,["flightNo","airCompanyName","cfts","arrivalTime"]]
    #print(result)
    remark=[[],[]]
    for i in result["cfts"]:
        remark[0].append(i[0]["ap"])
        remark[1].append(i[0]["cp"])
    remark=pd.DataFrame(remark).T
    remark.columns = ['first','second']
    df=pd.concat([result,remark],axis=1)
    df= df.drop(['cfts'],axis=1)
    print(df)
    pd.DataFrame(data).to_csv('机票价格.csv')
def save_to_csv(data):
    if not os.path.exists(r'2017-12-31.csv'):
        with open('2017-12-31.csv', 'a+', encoding='utf-8') as f:
            f.write('股票代码,股票简称,交易板块,截止日期,每股收益元,营业收入（元）,净利润,净资产收益率%,营业收入同比增长率%,净利润同比增长率%,每股净资产,每股经营现金流量,销售毛利率%,所属行业\n')
            for d in data:
                try:
                    row = '{},{},{},{},{},{},{},{},{},{},{},{},{},{}'.format(d['SECURITY_CODE'],
                                                                                            d['SECURITY_NAME_ABBR'],
                                                                                            d['TRADE_MARKET'],
                                                                                            d['REPORTDATE'],
                                                                                            d['BASIC_EPS'],
                                                                                            d['TOTAL_OPERATE_INCOME'],
                                                                                            d['PARENT_NETPROFIT'],
                                                                                            d['WEIGHTAVG_ROE'],
                                                                                            d['YSTZ'],
                                                                                            d['SJLTZ'],
                                                                                            d['BPS'],
                                                                                            d['MGJYXJJE'],
                                                                                            d['XSMLL'],
                                                                                            d['PUBLISHNAME'])
                    f.write(row)
                    f.write('\n')
                except:
                    continue
    else:
        with open('2017-12-31.csv', 'a+', encoding='utf-8') as f:
            for d in data:
                try:
                    row = '{},{},{},{},{},{},{},{},{},{},{},{},{},{}'.format(d['SECURITY_CODE'],
                                                                                            d['SECURITY_NAME_ABBR'],
                                                                                            d['TRADE_MARKET'],
                                                                                            d['REPORTDATE'],
                                                                                            d['BASIC_EPS'],
                                                                                            d['TOTAL_OPERATE_INCOME'],
                                                                                            d['PARENT_NETPROFIT'],
                                                                                            d['WEIGHTAVG_ROE'],
                                                                                            d['YSTZ'],
                                                                                            d['SJLTZ'],
                                                                                            d['BPS'],
                                                                                            d['MGJYXJJE'],
                                                                                            d['XSMLL'],
                                                                                            d['PUBLISHNAME'])
                    f.write(row)
                    f.write('\n')
                except:
                    continue

      


if __name__ == '__main__':
    get_data(data,headers)

# %%
#爬取酒店信息
a="https://www.ly.com/hotel/api/tmapi/search/hotellist"
headers={
    "Accept":"application/json,text/javascript,*/*;q=0.01",
    "Accept-Encoding":"gzip,deflate,br",
    "Accept-Language":"zh-CN,zh;q=0.9",
    "Connection":"keep-alive",
    "Content-Length":"542",
    "Content-Type":"application/x-www-form-urlencoded;charset=UTF-8",
    "Cookie":"GnHotelData=%7B%22CnHotelComeDate%22%3A%222020-07-10%22%2C%22CnHotelLeaveDate%22%3A%222020-07-11%22%2C%22CnHotelCityName%22%3A%22%25E5%258C%2597%25E4%25BA%25AC%22%2C%22CnHotelCityId%22%3A%2253%22%2C%22CnHotelParCityId%22%3A%220%22%2C%22Keyword%22%3A%22%22%2C%22KeywordId%22%3A%220%22%2C%22KeywordType%22%3A%220%22%2C%22Longitude%
    "Referer":"https://www.ly.com/searchlist.html?cityid=324&sectionid=0&comedate=2020-07-10&leavedate=2020-07-11&word=&wordid=0&wordtype=0&HotelType=0",
    "Sec-Fetch-Dest":"empty",
    "Sec-Fetch-Mode":"cors",
    "Sec-Fetch-Site":"same-origin",
    "User-Agent":"Mozilla/5.0(WindowsNT10.0;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/83.0.4103.97Safari/537.36",
    "X-Requested-With":"XMLHttpRequest"}
data={
    'CityId':324,
    'BizSectionId':0,
    'SectionId':0,
    'Word':'',
    'PriceRegion':'',
    'Range':'',
    'HotelStar':'',
    'ChainId':'',
    'HasStandBack':0,
    'Facilities':'',
    'BreakFast':'',
    'PayType':'',
    'SortType':0,
    'Instant':'',
    'LabelId':0,
    'WordType':0,
    'ThemeId':'',
    'Latitude':'',
    'Longitude':'',
    'ComeDate':'2020-07-12',
    'LeaveDate':'2020-07-13',
    'PageSize':20,
    'Page':1,
    'antitoken':'5e5fdf71369bdda0a614252208ac5453',
    'IsSeo':0,
    'iid':0.8228705045594424,
    'TraceId':'a86bc160-e4bd-4bf9-8500-fd2714bc98d6',
    'HotelType':0,
    'trace_token':'|*|cityId:2301|*|qId:d49d4284-9214-44a4-a057-d4deccfbe854|*|st:city|*|sId:2301|*|',
    'search_entrance_id':'tpc_home'}
headersd = { "Accept":"application/json, text/javascript, */*;q=0.01"}

    

import requests
from bs4 import BeautifulSoup
import os
import time
import pandas as pd
import json

def get_data(data,headers,i):
    url = a
    print(url)
    #json.dumps(data)
    data['Page']=i
    res1=requests.post(url,data=data,headers=headers)
    res1=res1.text
    data=res1.replace("null","None").replace("true","None").replace("false","None")
    data=eval(data)
    print(isinstance(data ,dict))
    data=data["HotelInfo"]
    #data=data["body"]["FlightInfoSimpleList"]
    if i==1:
        pd.DataFrame(data).to_csv('酒店.csv')
    else:
        pd.DataFrame(data).to_csv('酒店.csv', mode='a', header=False)
        
    #save_to_csv(data) 
def save_to_csv(data):
    if not os.path.exists(r'酒店.csv'):
        with open('酒店.csv', 'a+', encoding='utf-8') as f:
            f.write('股票代码,股票简称,交易板块,截止日期,每股收益元,营业收入（元）,净利润,净资产收益率%,营业收入同比增长率%,净利润同比增长率%,每股净资产,每股经营现金流量,销售毛利率%,所属行业\n')
            for d in data:
                try:
                    row = '{},{},{},{},{},{},{},{},{},{},{},{},{},{}'.format(d['SECURITY_CODE'],
                                                                                            d['SECURITY_NAME_ABBR'],
                                                                                            d['TRADE_MARKET'],
                                                                                            d['REPORTDATE'],
                                                                                            d['BASIC_EPS'],
                                                                                            d['TOTAL_OPERATE_INCOME'],
                                                                                            d['PARENT_NETPROFIT'],
                                                                                            d['WEIGHTAVG_ROE'],
                                                                                            d['YSTZ'],
                                                                                            d['SJLTZ'],
                                                                                            d['BPS'],
                                                                                            d['MGJYXJJE'],
                                                                                            d['XSMLL'],
                                                                                            d['PUBLISHNAME'])
                    f.write(row)
                    f.write('\n')
                except:
                    continue
    else:
        with open('酒店.csv', 'a+', encoding='utf-8') as f:
            for d in data:
                try:
                    row = '{},{},{},{},{},{},{},{},{},{},{},{},{},{}'.format(d['SECURITY_CODE'],
                                                                                            d['SECURITY_NAME_ABBR'],
                                                                                            d['TRADE_MARKET'],
                                                                                            d['REPORTDATE'],
                                                                                            d['BASIC_EPS'],
                                                                                            d['TOTAL_OPERATE_INCOME'],
                                                                                            d['PARENT_NETPROFIT'],
                                                                                            d['WEIGHTAVG_ROE'],
                                                                                            d['YSTZ'],
                                                                                            d['SJLTZ'],
                                                                                            d['BPS'],
                                                                                            d['MGJYXJJE'],
                                                                                            d['XSMLL'],
                                                                                            d['PUBLISHNAME'])
                    f.write(row)
                    f.write('\n')
                except:
                    continue

      


if __name__ == '__main__':
    for i in range(600,700):
        time.sleep(5)
        try:
            get_data(data,headers,i)
            print(i)
        except:
            print("error")
            print(i)
            continue

# %%
#爬取租房信息
a="https://sz.zu.ke.com/zufang/pg"
headers={
    "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "Accept-Encoding":"gzip,deflate,br",
    "Accept-Language":"zh-CN,zh;q=0.9",
    "Cache-Control":"max-age=0",
    "Connection":"keep-alive",
    "Cookie":"lianjia_ssid=7676d04d-b188-48ae-acba-3e559c16c4f3;lianjia_uuid=b010b866-4e49-4ed1-a49e-a6738246580f;select_city=440300;sajssdk_2015_cross_new_user=1;sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%221733d99c5002ee-099705de1f4f42-f7d123e-1049088-1733d99c501171%22%2C%22%24device_id%22%3A%221733d99c5002ee-099705de1f4f42-f7d123e-1049088-1733d99c501171%22%2C%22props%22%3A%7B%7D%7D;srcid=...",
    "Host":"sz.zu.ke.com",
    "Referer":"https//sz.zu.ke.com/zufang/pg3/",
    "Sec-Fetch-Dest":"document",
    "Sec-Fetch-Mode":"navigate",
    "Sec-Fetch-Site":"same-origin",
    "Sec-Fetch-User":"?1",
    "Upgrade-Insecure-Requests":"1",
    "User-Agent":"Mozilla/5.0(WindowsNT10.0;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/83.0.4103.97Safari/537.36",}
data={
   }

    

import requests
from bs4 import BeautifulSoup
import os
import time
import pandas as pd
import json

def get_data(data,headers,i):
    url = a+str(i)
    print(url)
    #json.dumps(data)
    res1=requests.get(url,headers=headers)
    res1=res1.text
    soup = BeautifulSoup(res1)
    soup=soup.find_all('div',class_='content__list--item')
    list=[[],[],[],[]]
    for i in soup:
        list[0].append(i.find_all('a')[0]["title"])#名称
        #print(i.find_all('p',class_='content__list--item--brand oneline'))
        list[1].append(i.find_all('span',class_='content__list--item-price')[0].text)#价格
        list[2].append(i.find_all('img')[0]["data-src"])#图片地址
        list[3].append(i.find_all('p',class_='content__list--item--des')[0].text.replace(" ","").replace("\n",""))#价格
    pd.DataFrame(list).T.to_csv('出租房.csv', mode='a', header=False,index=None)
if __name__ == '__main__':
    for i in range(1,1000):
        time.sleep(3)
        try:
            get_data(data,headers,i)
            print(i)
        except:
            print("error")
            print(i)
            continue
